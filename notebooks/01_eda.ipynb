# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
from pathlib import Path

DATA_DIR = "/Users/shshankj/Desktop/Projects/skin-cancer-ml/data"

if os.path.exists(DATA_DIR):
    print(f"✓ Dataset directory found: {DATA_DIR}")
else:
    print(f"✗ Dataset directory NOT found: {DATA_DIR}")
    print("Update DATA_DIR above to the correct path")
# Out:
# ✓ Dataset directory found: /Users/shshankj/Desktop/Projects/skin-cancer-ml/data

# %%
metadata = os.path.join(DATA_DIR, "HAM10000_metadata.csv")
df = pd.read_csv(metadata)

print(f"Data Frame Shape: \n {df.shape}")
print(f"\n First few rows:")
print(df.head())
print(f"\nColumn names:")
# Out:
# Data Frame Shape:
#  (10015, 7)
#
#  First few rows:
#      lesion_id      image_id   dx dx_type   age   sex localization
# 0  HAM_0000118  ISIC_0027419  bkl   histo  80.0  male        scalp
# 1  HAM_0000118  ISIC_0025030  bkl   histo  80.0  male        scalp
# 2  HAM_0002730  ISIC_0026769  bkl   histo  80.0  male        scalp
# 3  HAM_0002730  ISIC_0025661  bkl   histo  80.0  male        scalp
# 4  HAM_0001466  ISIC_0031633  bkl   histo  75.0  male          ear
#
# Column names:
